# %%
import pandas as pd

df = pd.read_csv("jitensha.csv")
df.head()
# Out:
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自動車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自動車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自動車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自動車盗       千葉中央         本千葉駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自動車盗       千葉中央           西千葉      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細  施錠関係 盗難防止装置の有無  \
# 0      青葉町  20241008      18                一戸建住宅  駐車（輪）場  キーなし        あり
# 1    末広３丁目  20231230      10  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場  キーあり        なし
# 2     千葉寺町  20240621      12               駐車（輪）場  駐車（輪）場  キーなし        なし
# 3   寒川町１丁目  20241122       5                  その他     その他  キーあり        なし
# 4     汐見丘町  20240114      14               駐車（輪）場  駐車（輪）場  キーなし        なし
#
#   現金以外の主な被害品
# 0      乗用自動車
# 1      貨物自動車
# 2      乗用自動車
# 3      貨物自動車
# 4      乗用自動車

# %%
df.groupby('市区町村（発生地）').size().sort_values(ascending=False)
# Out:
# 市区町村（発生地）
# 柏市         57
# 松戸市        52
# 印西市        51
# 野田市        49
# 市川市        42
# 船橋市        40
# 千葉市花見川区    37
# 千葉市若葉区     29
# 流山市        29
# 市原市        26
# 成田市        23
# 佐倉市        21
# 我孫子市       21
# 八千代市       17
# 浦安市        17
# 千葉市中央区     16
# 四街道市       15
# 千葉市美浜区     15
# 富里市        14
# 千葉市稲毛区     12
# 千葉市緑区      12
# 八街市        11
# 白井市        11
# 鎌ケ谷市        9
# 香取市         9
# 習志野市        8
# 東金市         8
# 木更津市        7
# 山武市         7
# 銚子市         5
# 旭市          5
# 大網白里市       4
# 茂原市         4
# 酒々井町        3
# 鴨川市         2
# 多古町         2
# 君津市         2
# 袖ケ浦市        2
# 栄町          2
# 九十九里町       1
# 大多喜町        1
# 匝瑳市         1
# 富津市         1
# 東庄町         1
# 横芝光町        1
# 長柄町         1
# 館山市         1
# 長生村         1
# dtype: int64

# %%
df['発生日'] = pd.to_datetime(df['発生年月日（始期）'], format="%Y%m%d", errors='coerce')
df['月'] = df['発生日'].dt.month
df.groupby('月').size()
# Out:
# 月
# 1.0     76
# 2.0     57
# 3.0     81
# 4.0     54
# 5.0     61
# 6.0     60
# 7.0     51
# 8.0     57
# 9.0     59
# 10.0    61
# 11.0    45
# 12.0    35
# dtype: int64

# %%
monthly_counts = df.groupby('月').size().sort_values(ascending=False)
ranked = monthly_counts.reset_index(name='件数')
ranked['ランク'] = ranked['件数'].rank(method='min', ascending=False).astype(int)
print(ranked)
# Out:
#        月  件数  ランク
# 0    3.0  81    1
# 1    1.0  76    2
# 2   10.0  61    3
# 3    5.0  61    3
# 4    6.0  60    5
# 5    9.0  59    6
# 6    8.0  57    7
# 7    2.0  57    7
# 8    4.0  54    9
# 9    7.0  51   10
# 10  11.0  45   11
# 11  12.0  35   12

# %%
# bar graph of 被害者の職業
import  as jitensha.csv plt

# fix japanese font issue for mac
plt.rcParams['font.family'] = 'Hiragino Sans'

# fix japanese font issue for windows
plt.rcParams['font.family'] = 'MS Gothic'

occupation_counts = df['被害者の職業'].value_counts().head(10)  # top 10 occupations
occupation_counts.plot(kind='bar')
plt.xlabel('被害者の職業')
plt.ylabel('件数')
plt.title('被害者の職業別自転車盗難件数（上位10件）')
plt.show()
# Out:
#   Cell In[11], line 2
#     import  as jitensha.csv plt
#             ^
# SyntaxError: invalid syntax
